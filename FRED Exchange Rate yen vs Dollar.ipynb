# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import math
import seaborn as sns
from random import sample

# %%
import datetime
import matplotlib as mpl
# %matplotlib inline

# %%
import pandas_datareader.data as data
tstart = datetime.datetime(2019, 1, 1)
tend = datetime.datetime(2020, 1, 1)
#get the EURUSD exchange rate
exuseu = data.DataReader("DEXJPUS", "fred", tstart, tend);
print(type(exuseu))
print(exuseu.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             DEXJPUS
# DATE
# 2016-03-31   112.42
# 2016-04-01   112.06
# 2016-04-04   111.18
# 2016-04-05   110.26
# 2016-04-06   109.63

# %%
print(exuseu.index) #this is a DatetimeIndex
print(exuseu.describe())
# Out:
# DatetimeIndex(['2016-03-31', '2016-04-01', '2016-04-04', '2016-04-05',
#                '2016-04-06', '2016-04-07', '2016-04-08', '2016-04-11',
#                '2016-04-12', '2016-04-13',
#                ...
#                '2021-03-15', '2021-03-16', '2021-03-17', '2021-03-18',
#                '2021-03-19', '2021-03-22', '2021-03-23', '2021-03-24',
#                '2021-03-25', '2021-03-26'],
#               dtype='datetime64[ns]', name='DATE', length=1302, freq=None)
#            DEXJPUS
# count  1244.000000
# mean    108.947130
# std       3.361718
# min     100.070000
# 25%     106.640000
# 50%     109.140000
# 75%     111.410000
# max     118.320000

# %%
ax1 = exuseu.plot(marker = 'o')
plt.grid(True)
plt.title("Japan / U.S. Foreign Exchange Rate")
plt.ylabel("Japanese Yen to One Dollar")
# Out:
# Text(0, 0.5, 'Japanese Yen to One Dollar')
